# %%
# kulllanicadan 1,2,3,4 seklinde alinan rastgele sayilarin uzunlugunu bulunuz.
a = input("1,3,4,5 seklinde girilen degerleri giriniz: ").split(',')
print(f"Eleman sayisi:  {len(a)}")
# Out:
# 1,3,4,5 seklinde girilen degerleri giriniz: 1,2,3,4
# Eleman sayisi:  4

# %%
# kulllanicadan 1,2,3,4 4 elemanli rastgele sayilarin ortalamasini bulunuz.
input_1 = input("1,23,4 seklinde sayilari giriniz: ")
sayilar = input_1.split(',')
(int(sayilar[0]) + int(sayilar[1]) + int(sayilar[2]) + int(sayilar[3])) / 4
# Out:
# 1,23,4 seklinde sayilari giriniz: 10,10,10,10
# 10.0

# %%
sayilar = list(map(int,input("1,2,3 formatinda eleman giriniz: ").split(",")))

print(sum(sayilar)/len(sayilar))

# %%
# kulllanicadan 3,4,1,9,6 seklinde alinan rastgele sayilarin ortanca degerini bulunuz.
a = input("3,4,1,9,6 seklinde sayilari giriniz: ").split(',')
print(a)
liste = []
for i in a:
    #print(int(i),type(int(i)))
    liste.append(int(i))

print(liste)
liste.sort()
print(liste)
ortanca = len(liste)//2
print(ortanca)
print(liste[ortanca])
# Out:
# 3,4,1,9,6 seklinde sayilari giriniz: 11,10,100,20,9
# ['11', '10', '100', '20', '9']
# [11, 10, 100, 20, 9]
# [9, 10, 11, 20, 100]
# 2
# 11

# %%
# kulllanicadan 1,2,3,4 seklinde alinan  4 rastgele sayilarin kareleri toplamini bulunuz.
a = input("1,2,3,4 seklinde sayilari giriniz: ").split(',')
int(a[0]) **2 + int(a[1]) **2 + int(a[2]) **2 + int(a[3])**2
# Out:
# 1,2,3,4 seklinde sayilari giriniz: 1,2,3,4
# 30

# %%
# kulllanicadan 1.1,2.3,3.1,4 seklinde alinan  4 rastgele sayilarin ortalamasini bulunuz.
a = input("1.1,2.3,3.1,4 seklinde sayilari giriniz: ").split(',')
(float(a[0]) + float(a[1]) + float(a[2]) + float(a[3])) / len(a)
# Out:
# 1.1,2.3,3.1,4 seklinde sayilari giriniz: 1,2,3,4
# 2.5

# %%
# kulllanicadan  alinan metnin uzunlugunu bulunuz.
a = input("Bir metin giriniz: ")
print(len(a))
# Out:
# Bir metin giriniz: merhaba dunya
# 13

# %%
# kulllanicadan  alinan metnin karakter sayisini bulunuz.
#merhaba dunya \n \t
"merhaba dunya\n \t   \n".replace(" ","").replace("\n","").replace("\t","")
# Out:
# 'merhabadunya'

# %%
# kulllanicadan  alinan metni tumunu buyuk harfe donusturunuz.

# %%
# girilen metinde 'a' harfi geciyormu kontrol ediniz.
'abcdef'.find('a')
'bcdef'.count('a')
'a' in 'bcdef'
# Out:
# False

# %%
1 in [1,2,3,4]
# Out:
# True

# %%
#  girilen metinde 'a' harfi kac defa geciyor.
'abcdefaa'.count('a')
# Out:
# 3

# %%
# 1,2,3 girilen ifadeyi 1-2-3 seklinde donusturunuz.
'1,2,3'.replace(",","-")
'-'.join('1,2,3'.split(','))
# Out:
# '1-2-3'

# %%
x = ['a','b','c']
y = '-'.join(x)

# %%
y,type(y)
# Out:
# ('a-b-c', str)
