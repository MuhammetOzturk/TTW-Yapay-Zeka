# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://gist.githubusercontent.com/MuhammetOzturk/caf476e7b51c2be4aca2e60d53007b2a/raw/15ed8c1dd2215bba1b2ff3fc0655b9ea206d75b6/Titanic.csv'

df = pd.read_csv(url)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().round(2)
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count       891.00    891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00      0.38    2.31   29.70    0.52    0.38   32.20
# std         257.35      0.49    0.84   14.53    1.10    0.81   49.69
# min           1.00      0.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50      0.00    2.00   20.12    0.00    0.00    7.91
# 50%         446.00      0.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50      1.00    3.00   38.00    1.00    0.00   31.00
# max         891.00      1.00    3.00   80.00    8.00    6.00  512.33

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(866)

# %%
np.sum(df.isna().to_numpy())
# Out:
# np.int64(866)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.columns = ['YolcuId','Kurtuldumu', 'Sinif', 'Isim', 'Cinsiyet','Yas','Es/Kardes', 'Ebeveyn/Cocuk','BiletNo','Ucret','Kabin','Liman']
df.columns
# Out:
# Index(['YolcuId', 'Kurtuldumu', 'Sinif', 'Isim', 'Cinsiyet', 'Yas',
#        'Es/Kardes', 'Ebeveyn/Cocuk', 'BiletNo', 'Ucret', 'Kabin', 'Liman'],
#       dtype='object')

# %%
df.iloc[:,1:].hist(figsize=(10,8))
plt.tight_layout()

# %% [markdown]
# ```python
# df.loc[:,'Cinsiyet'] = df.Cinsiyet.map({'male':'erkek','female':'kadin'})
# df.head()
# ```

# %%
df.loc[df.Cinsiyet == 'male','Cinsiyet'] = 'Erkek'
df.loc[df.Cinsiyet == 'female','Cinsiyet'] = 'Kadin'
df.head()
# Out:
#    YolcuId  Kurtuldumu  Sinif  \
# 0        1           0      3
# 1        2           1      1
# 2        3           1      3
# 3        4           1      1
# 4        5           0      3
#
#                                                 Isim Cinsiyet   Yas  \
# 0                            Braund, Mr. Owen Harris    Erkek  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    Kadin  38.0
# 2                             Heikkinen, Miss. Laina    Kadin  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    Kadin  35.0
# 4                           Allen, Mr. William Henry    Erkek  35.0
#
#    Es/Kardes  Ebeveyn/Cocuk           BiletNo    Ucret Kabin Liman
# 0          1              0         A/5 21171   7.2500   NaN     S
# 1          1              0          PC 17599  71.2833   C85     C
# 2          0              0  STON/O2. 3101282   7.9250   NaN     S
# 3          1              0            113803  53.1000  C123     S
# ...

# %%
# Alternatif
df.replace({'Erkek':'erkek','Kadin':'kadin'},inplace=True)
df.head()
# Out:
#    YolcuId  Kurtuldumu  Sinif  \
# 0        1           0      3
# 1        2           1      1
# 2        3           1      3
# 3        4           1      1
# 4        5           0      3
#
#                                                 Isim Cinsiyet   Yas  \
# 0                            Braund, Mr. Owen Harris    erkek  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    kadin  38.0
# 2                             Heikkinen, Miss. Laina    kadin  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    kadin  35.0
# 4                           Allen, Mr. William Henry    erkek  35.0
#
#    Es/Kardes  Ebeveyn/Cocuk           BiletNo    Ucret Kabin Liman
# 0          1              0         A/5 21171   7.2500   NaN     S
# 1          1              0          PC 17599  71.2833   C85     C
# 2          0              0  STON/O2. 3101282   7.9250   NaN     S
# 3          1              0            113803  53.1000  C123     S
# ...

# %%
df.Liman.replace({'Q':'Queenstown','C':'Cherbourg','S':'Southampton'},inplace=True)
df.head()
# Out:
# /tmp/ipython-input-221-3229475477.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Liman.replace({'Q':'Queenstown','C':'Cherbourg','S':'Southampton'},inplace=True)
#    YolcuId  Kurtuldumu  Sinif  \
# 0        1           0      3
# 1        2           1      1
# 2        3           1      3
# 3        4           1      1
# 4        5           0      3
#
#                                                 Isim Cinsiyet   Yas  \
# 0                            Braund, Mr. Owen Harris    erkek  22.0
# ...

# %%
#Normal de olmasi gereken kullanim
df.Liman = df.Liman.replace({'Q':'Queenstown','C':'Cherbourg','S':'Southampton'})
df.head()
# Out:
#    YolcuId  Kurtuldumu  Sinif  \
# 0        1           0      3
# 1        2           1      1
# 2        3           1      3
# 3        4           1      1
# 4        5           0      3
#
#                                                 Isim Cinsiyet   Yas  \
# 0                            Braund, Mr. Owen Harris    erkek  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    kadin  38.0
# 2                             Heikkinen, Miss. Laina    kadin  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    kadin  35.0
# 4                           Allen, Mr. William Henry    erkek  35.0
#
#    Es/Kardes  Ebeveyn/Cocuk           BiletNo    Ucret Kabin        Liman
# 0          1              0         A/5 21171   7.2500   NaN  Southampton
# 1          1              0          PC 17599  71.2833   C85    Cherbourg
# 2          0              0  STON/O2. 3101282   7.9250   NaN  Southampton
# ...

# %%
df.Cinsiyet.hist()
plt.show()

# %%
df.Sinif.hist()
plt.xticks([1,2,3],['1.Sinif','2.Sinif','3.Sinif'],rotation=45)
plt.yticks(rotation=-45)
plt.show()

# %%
df.Kurtuldumu.hist()
plt.xticks([0,1],['Kurtulamadi','Kurtuldu'],rotation=0)
plt.show()

# %%
df.Liman.hist()
plt.show()

# %%
df.loc[df.Liman == 'Southampton','Sinif'].hist()
plt.xticks([1,2,3],['1.Sinif','2.Sinif','3.Sinif'],rotation=45)
plt.yticks(rotation=-45)
plt.show()

# %%
df.loc[df.Liman == 'Southampton','Kurtuldumu'].hist()
plt.xticks([0,1],['Kurtulamadi','Kurtuldu'],rotation=0)
plt.show()

# %%
df.loc[df.Liman == 'Queenstown','Kurtuldumu'].hist()
plt.xticks([0,1],['Kurtulamadi','Kurtuldu'],rotation=0)
plt.show()

# %%
df.loc[df.Liman == 'Cherbourg','Kurtuldumu'].hist()
plt.xticks([0,1],['Kurtulamadi','Kurtuldu'],rotation=0)
plt.show()

# %%
df.loc[(df.Liman == 'Cherbourg') ,'Cinsiyet'].hist()
plt.show()

# %%
df.loc[(df.Liman == 'Cherbourg') & (df.Kurtuldumu == 1) & (df.Sinif == 1),'Cinsiyet'].hist()
plt.show()

# %%
df.loc[(df.Liman == 'Cherbourg') & (df.Kurtuldumu == 1) & (df.Sinif == 3),'Cinsiyet'].hist()
plt.show()

# %%
df.loc[(df.Liman == 'Cherbourg') & (df.Kurtuldumu == 1) & (df.Sinif == 2),'Cinsiyet'].hist()
plt.show()

# %%
df_temp = df.loc[(df.Liman == 'Cherbourg') & (df.Kurtuldumu == 1) ,['Cinsiyet','Sinif']]
# Out:
#     Cinsiyet  Sinif
# 1      kadin      1
# 9      kadin      2
# 19     kadin      3
# 31     kadin      1
# 36     erkek      3
# ..       ...    ...
# 866    kadin      2
# 874    kadin      2
# 875    kadin      3
# 879    kadin      1
# 889    erkek      1
#
# [93 rows x 2 columns]
