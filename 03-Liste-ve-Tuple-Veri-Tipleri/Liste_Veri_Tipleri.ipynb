# %%
liste = []
print(f"{liste} --> eleman sayisi : {len(liste)}")
# Out:
# [] --> eleman sayisi : 0

# %%
liste = [1,2,3,4,5]
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# [1, 2, 3, 4, 5] --> eleman sayisi: 5

# %%
liste[0]
# Out:
# 1

# %%
liste[1]
# Out:
# 2

# %%
liste[:3]
# Out:
# [1, 2, 3]

# %%
liste[::-1]
# Out:
# [5, 4, 3, 2, 1]

# %%
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# [1, 2, 3, 4, 5] --> eleman sayisi: 5

# %%
liste = [1,2,True,"a"]
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# [1, 2, True, 'a'] --> eleman sayisi: 4

# %%
liste[-2]
# Out:
# True

# %%
liste[-2:]
# Out:
# [True, 'a']

# %%
liste[-1] = 10
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# [1, 2, True, 10] --> eleman sayisi: 4

# %%
liste[-2:] = 100,110
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# [1, 2, 100, 110] --> eleman sayisi: 4

# %%
# append sona ekleme yapar.
liste.append("a")
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# [1, 2, 100, 110, 'a'] --> eleman sayisi: 5

# %%
# insert verilen indis degerine ekleme yapar.
liste.insert(0,"Merhaba Dunya")
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# ['Merhaba Dunya', 1, 2, 100, 110, 'a'] --> eleman sayisi: 6

# %%
liste.append([0,1,2])
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# ['Merhaba Dunya', 1, 2, 100, 110, 'a', [0, 1, 2]] --> eleman sayisi: 7

# %%
# extend verilen degerin elamanlarini acarak ekler.
liste.extend([[3,4,5]])
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# ['Merhaba Dunya', 1, 2, 100, 110, 'a', [0, 1, 2], [3, 4, 5]] --> eleman sayisi: 8

# %%
liste.extend([[6,7,8]])
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# ['Merhaba Dunya', 1, 2, 100, 110, 'a', [0, 1, 2], [3, 4, 5], [6, 7, 8]] --> eleman sayisi: 9

# %%
liste.append(100)
liste
# Out:
# ['Merhaba Dunya', 1, 2, 100, 110, 'a', [0, 1, 2], [3, 4, 5], [6, 7, 8], 100]

# %%
# remove ilk buldugu degeri siler.
liste.remove(100)

# %%
print(f"{liste} --> eleman sayisi: {len(liste)}")
# Out:
# ['Merhaba Dunya', 1, 2, 110, 'a', [0, 1, 2], [3, 4, 5], [6, 7, 8], 100] --> eleman sayisi: 9

# %%
# remove fonksiyonunda olmayan deger silinmeye calisildiginda hata verir
# yani kod coker
liste.remove('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-507840433.py in <cell line: 0>()
# ----> 1 liste.remove('x')
#
# ValueError: list.remove(x): x not in list

# %%
# pop fonksiyonu silinen degeri geri donderir.
liste.pop()
liste
# Out:
# ['Merhaba Dunya', 1, 2, 110, 'a', [0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
silinen = liste.pop()
print(f"{silinen} --> eleman sayisi: {len(liste)}")
# Out:
# [6, 7, 8] --> eleman sayisi: 7

# %%
liste.pop(-1)
# Out:
# [3, 4, 5]

# %%
liste
# Out:
# ['Merhaba Dunya', 1, 2, 110, 'a', [0, 1, 2]]

# %%
liste.pop(0)
# Out:
# 'Merhaba Dunya'

# %%
liste
# Out:
# [1, 2, 110, 'a', [0, 1, 2]]

# %%
liste.index('a')
# Out:
# 3

# %%
liste.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3940986113.py in <cell line: 0>()
# ----> 1 liste.index(0)
#
# ValueError: 0 is not in list

# %%
liste.append(1)
liste
# Out:
# [1, 2, 110, 'a', [0, 1, 2], 1]

# %%
liste.count(1)
# Out:
# 2

# %%
yeni_liste = [10,2,8,5,2,2,3,4]

# %%
yeni_liste.sort()

# %%
print(f"{yeni_liste} --> eleman sayisi: {len(yeni_liste)}")
# Out:
# [2, 2, 2, 3, 4, 5, 8, 10] --> eleman sayisi: 8

# %%
yeni_liste = ['ab', 'ba', 'aa','c','d','cz','ca']
yeni_liste.sort()

# %%
print(f"{yeni_liste} --> eleman sayisi: {len(yeni_liste)}")
# Out:
# ['aa', 'ab', 'ba', 'c', 'ca', 'cz', 'd'] --> eleman sayisi: 7

# %%
yeni_liste.sort(reverse=True)
print(f"{yeni_liste} --> eleman sayisi: {len(yeni_liste)}")
# Out:
# ['d', 'cz', 'ca', 'c', 'ba', 'ab', 'aa'] --> eleman sayisi: 7

# %%
yeni_liste = [10,2,8,5,2,2,3,4]
yeni_liste.reverse()
print(f"{yeni_liste} --> eleman sayisi: {len(yeni_liste)}")
# Out:
# [4, 3, 2, 2, 5, 8, 2, 10] --> eleman sayisi: 8

# %%
girdi = input("Isim soyisim giriniz: ")
isim, soyisim = girdi.split(" ")
print(f"isim: {isim} soyisim: {soyisim}")
# Out:
# Isim soyisim giriniz: muhammet ozturk
# isim: muhammet soyisim: ozturk

# %%
isim, *soyisim = input("Isim soyisim giriniz: ").split(" ")
print(f"isim: {isim} soyisim: {soyisim}")
# Out:
# Isim soyisim giriniz: sezen nur bulusan
# isim: sezen soyisim: ['nur', 'bulusan']

# %%
isim.upper()
# Out:
# 'SEZEN'

# %%
isim = isim[0].upper() + isim[1:]
isim
# Out:
# 'Sezen'

# %%
isim, soyisim = "muhammet ozturk".split()
isim.capitalize(),soyisim.capitalize()
# Out:
# ('Muhammet', 'Ozturk')

# %%
'muhammet ozturk'.title()
# Out:
# 'Muhammet Ozturk'

# %%
"sezen nur bulusan".title()
# Out:
# 'Sezen Nur Bulusan'

# %%
a,*b, c = [1,2,3,4,5]
print(f"a:{a} b:{b} c:{c}")
# Out:
# a:1 b:[2, 3, 4] c:5
