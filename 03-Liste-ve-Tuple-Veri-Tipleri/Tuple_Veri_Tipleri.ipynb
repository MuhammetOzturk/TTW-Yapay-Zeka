# %%
t = ()
print(f"{t} eleman sayisi: {len(t)}")
# Out:
# () eleman sayisi: 0

# %%
t = (1,2,3,"a",1,2)
print(f"{t} eleman sayisi: {len(t)}")
# Out:
# (1, 2, 3, 'a', 1, 2) eleman sayisi: 6

# %%
t[0:2]
# Out:
# (1, 2)

# %%
t[-1]
# Out:
# 2

# %%
t[-3:]
# Out:
# ('a', 1, 2)

# %%
t[:3]
# Out:
# (1, 2, 3)

# %%
t[::2]
# Out:
# (1, 3, 1)

# %%
t[::-1]
# Out:
# (2, 1, 'a', 3, 2, 1)

# %%
t[0] = "Merhaba Dunya"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2513448316.py in <cell line: 0>()
# ----> 1 t[0] = "Merhaba Dunya"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t
# Out:
# (1, 2, 3, 'a', 1, 2)

# %%
t.count('a')
# Out:
# 1

# %%
t.index('a')
# Out:
# 3

# %%
t.index(2)
# Out:
# 1

# %%
t3 = list(t)
print(f"t3 = {t3} eleman sayisi: {len(t3)}")
# Out:
# t3 = [1, 2, 3, 'a', 1, 2] eleman sayisi: 6

# %%
t3[0] = "Merhaba Dunya"
t3
# Out:
# ['Merhaba Dunya', 2, 3, 'a', 1, 2]

# %%
t4 = tuple(t3)
print(f"t4 = {t4} eleman sayisi: {len(t4)}")
# Out:
# t4 = ('Merhaba Dunya', 2, 3, 'a', 1, 2) eleman sayisi: 6

# %%
server_anahtarlari = ("abcdef", "ijklmno")
liste_keyler = list(server_anahtarlari)
liste_keyler[0] = "xyz"
server_anahtarlari = tuple(liste_keyler)
print(f"Keyler : {server_anahtarlari} {type(server_anahtarlari)}")
# Out:
# Keyler : ('xyz', 'ijklmno') <class 'tuple'>
