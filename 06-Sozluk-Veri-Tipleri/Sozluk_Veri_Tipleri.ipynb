# %%
sozluk = {1:"bir", 2:"iki", 3:"uc"}
print(sozluk, type(sozluk))
# Out:
# {1: 'bir', 2: 'iki', 3: 'uc'} <class 'dict'>

# %%
sozluk.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
sozluk.values()
# Out:
# dict_values(['bir', 'iki', 'uc'])

# %%
items = sozluk.items()
yeni_liste = list(items)
yeni_liste[0],type(yeni_liste[0])
# Out:
# ((1, 'bir'), tuple)

# %%
kume = {1,"bir",2,"iki",3,"uc",1,1,1}
print(kume, type(kume))
# Out:
# {1, 2, 3, 'iki', 'uc', 'bir'} <class 'set'>

# %%
sozluk = {'name':'isim', 'look':'bakmak'}
print(f"{sozluk} {type(sozluk)} {len(sozluk)}")
# Out:
# {'name': 'isim', 'look': 'bakmak'} <class 'dict'> 2

# %%
#sozluklerde anahtar degerleri degistirilemez veri tiplerinden olmak zorunda
sozluk2 = {(1,2):'isim', 'look':'bakmak'}

# %%
sozluk['name'],sozluk['look']
# Out:
# ('isim', 'bakmak')

# %%
sozluk['eye']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3170393312.py in <cell line: 0>()
# ----> 1 sozluk['eye']
#
# KeyError: 'eye'

# %%
sozluk.get('name')
# Out:
# 'isim'

# %%
sozluk.get('eye')

# %%
sozluk.get('eye','Boyle bir anahtar degeri yok')
# Out:
# 'Boyle bir anahtar degeri yok'

# %%
sozluk['name'] = "ad"
print(sozluk)
# Out:
# {'name': 'ad', 'look': 'bakmak'}

# %%
sozluk['look'] = "gormek"
print(sozluk)
# Out:
# {'name': 'ad', 'look': 'gormek'}

# %%
sozluk['happy'] = 'mutlu'
print(sozluk)
# Out:
# {'name': 'ad', 'look': 'gormek', 'happy': 'mutlu'}

# %%
kullanici = {'email':'xxx@gmail.com', 'password':'123456'}
print(kullanici)
# Out:
# {'email': 'xxx@gmail.com', 'password': '123456'}

# %%
kullanici = {'isim':'Ahmet', 'soyisim':'Yılmaz', 'email':'xxx@gmail.com', 'password':'123456'}
print(kullanici)
# Out:
# {'isim': 'Ahmet', 'soyisim': 'Yılmaz', 'email': 'xxx@gmail.com', 'password': '123456'}

# %%
kullanici.keys()
# Out:
# dict_keys(['isim', 'soyisim', 'email', 'password'])

# %%
kullanici.values()
# Out:
# dict_values(['Ahmet', 'Yılmaz', 'xxx@gmail.com', '123456'])

# %%
kullanici['isim']
# Out:
# 'Ahmet'

# %%
liste = [1,2,3]
liste[0]
# Out:
# 1

# %%
# pop fonksiyonu verilen anahtar degerine karsilik gelen bilgiyi siler ,sildigi geri donderir
kullanici.pop('email')
print(kullanici)
kullanici.pop('password')
#kullanici.popitem()
print(kullanici)
# Out:
# {'isim': 'Ahmet', 'soyisim': 'Yılmaz', 'password': '123456'}
# {'isim': 'Ahmet', 'soyisim': 'Yılmaz'}

# %%
# popitem sozluk'teki son elemani siler
kullanici.popitem()
print(kullanici)
# Out:
# {'isim': 'Ahmet'}

# %%
kullanici.clear()
print(kullanici,len(kullanici))
# Out:
# {} 0

# %%
kullanici = {'isim':'Ahmet', 'soyisim':'Yılmaz', 'email':'xxx@gmail.com', 'password':'123456'}
kullanici.pop('password')
# Out:
# '123456'

# %%
liste = [1,2,3]
liste.pop(2)
# Out:
# 3

# %%
kullanici = {'isim':'Ahmet', 'soyisim':'Yılmaz', 'email':'xxx@gmail.com', 'password':'123456'}
kullanici.items()
# Out:
# dict_items([('isim', 'Ahmet'), ('soyisim', 'Yılmaz'), ('email', 'xxx@gmail.com'), ('password', '123456')])

# %%
bilgi = list(kullanici.items())
bilgi[0],bilgi[1]
# Out:
# (('isim', 'Ahmet'), ('soyisim', 'Yılmaz'))

# %%
yeni_bilgi = {'dogum_tarihi':'1990', 'dogum_yeri': 'Erzurum',}
kullanici.update(yeni_bilgi)
print(kullanici)
# Out:
# {'isim': 'Ahmet', 'soyisim': 'Yılmaz', 'email': 'xxx@gmail.com', 'password': '123456', 'dogum_tarihi': '1990', 'dogum_yeri': 'Erzurum'}

# %%
kullanici.update({'dogum_yeri':'Istanbul'})
print(kullanici)
# Out:
# {'isim': 'Ahmet', 'soyisim': 'Yılmaz', 'email': 'xxx@gmail.com', 'password': '123456', 'dogum_tarihi': '1990', 'dogum_yeri': 'Istanbul'}
