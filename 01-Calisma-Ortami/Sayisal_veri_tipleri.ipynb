# %%
a = 1
a
# Out:
# 1

# %%
print(a)
# Out:
# 1

# %% [markdown]
# **print**: `print` fonksiyonu cikti alanina yazi yazdirir.

# %%
# int veri = tam sayi
type(a)
# Out:
# int

# %%
a = 1.1
a
# Out:
# 1.1

# %%
print(a)
# Out:
# 1.1

# %%
# float = ondalikli sayi
type(a)
# Out:
# float

# %%
a = 10
b = 2
print(f"1.sayi = {a}",
      f"2.sayi = {b}")
# Out:
# 1.sayi = 10 2.sayi = 2

# %%
# Toplam islemi
a + b
# Out:
# 12

# %%
# Cikarma islemi
a - b
# Out:
# 8

# %%
# Bolme islemi
a / b
# Out:
# 5.0

# %%
# Carpma islemi
a * b
# Out:
# 20

# %%
a = input("Bir sayi giriniz : ")
# Out:
# Bir sayi giriniz : 12

# %%
print(a, type(a))
# Out:
# 12 <class 'str'>

# %%
b = int(a)
print(b, type(b))
# Out:
# 12 <class 'int'>

# %%
b + 10
# Out:
# 22

# %%
 11 + 10
# Out:
# 21

# %%
'a' + 'b'
# Out:
# 'ab'
