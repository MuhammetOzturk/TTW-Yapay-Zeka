# %%
a = 1
a
# Out:
# 1

# %%
print(a)
# Out:
# 1

# %% [markdown]
# **print**: `print` fonksiyonu cikti alanina yazi yazdirir.

# %%
# int veri = tam sayi
type(a)
# Out:
# int

# %%
a = 1.1
a
# Out:
# 1.1

# %%
print(a)
# Out:
# 1.1

# %%
# float = ondalikli sayi
type(a)
# Out:
# float

# %%
a = 10
b = 2
print(f"1.sayi = {a}",
      f"2.sayi = {b}")
# Out:
# 1.sayi = 10 2.sayi = 2

# %%
# Toplam islemi
a + b
# Out:
# 12

# %%
# Cikarma islemi
a - b
# Out:
# 8

# %%
# Bolme islemi
a / b
# Out:
# 5.0

# %%
# Carpma islemi
a * b
# Out:
# 20

# %%
a = input("Bir sayi giriniz : ")
# Out:
# Bir sayi giriniz : 12

# %%
print(a, type(a))
# Out:
# 12 <class 'str'>

# %%
b = int(a)
print(b, type(b))
# Out:
# 12 <class 'int'>

# %%
b + 10
# Out:
# 22

# %%
 11 + 10
# Out:
# 21

# %%
'a' + 'b'
# Out:
# 'ab'

# %%
2 ** 3
# Out:
# 8

# %%
a = 3
a ** 2
# Out:
# 9

# %%
pow(a, 2)
# Out:
# 9

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
# tam boleni elde etmek kullanilir.
# Ek aciklama
a = 10
a // 3
# Out:
# 3

# %%
"Ornek aciklama"
print("Merhaba Dunya")
# Out:
# Merhaba Dunya

# %%
""""
Aciklama 1
Aciklama 2
"""
print("Merhaba Dunya.")
# Out:
# Merhaba Dunya.

# %%
'Ornek Aciklama'
print("Merhaba Dunya")
# Out:
# Merhaba Dunya

# %%
'''
Aciklama 1
Aciklama 2
'''
print("Merhaba Dunya")
# Out:
# Merhaba Dunya

# %%
# sphinx python dokumantosyon araci
def topla(a, b):
    "Bu fonksiyon iki ifadeyi toplar."
    #print(a + b)
    return a + b


print(topla(10,20) + topla(1,1))
help(topla)
# Out:
# 32
# Help on function topla in module __main__:
#
# topla(a, b)
#     Bu fonksiyon iki ifadeyi toplar.

# %%
abs(-10)
# Out:
# 10

# %%
round(3.5879,1)
# Out:
# 3.6
