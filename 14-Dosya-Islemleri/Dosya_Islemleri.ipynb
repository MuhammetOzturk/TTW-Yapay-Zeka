# %%
# !pwd
# Out:
# /content

# %%
# !touch ornek.text

# %%
# !echo -n "Merhaba Dunya" > ornek.text

# %%
fd = open("ornek.text")

# %%
icerik = fd.read()
print(icerik)
fd.close()
# Out:
# Merhaba Dunya

# %%
fd2 = open("ornek.text","w")

# %%
fd2.write('Merhaba Muhammet')
fd2.close()

# %%
fd3 = open('ornek.text','r+')
fd3.read()
fd3.write('\nMerhaba Mustafa')
fd3.close()
