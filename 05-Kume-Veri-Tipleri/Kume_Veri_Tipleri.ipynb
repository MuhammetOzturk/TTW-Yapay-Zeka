# %%
kume = set()
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# set() tipi: <class 'set'> eleman sayısı: 0

# %%
kume = {1,2,3,3,3}
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# {1, 2, 3} tipi: <class 'set'> eleman sayısı: 3

# %%
kume.add(1)
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# {1, 2, 3} tipi: <class 'set'> eleman sayısı: 3

# %%
kume.add(1)
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# {1, 2, 3} tipi: <class 'set'> eleman sayısı: 3

# %%
kume.add(2)
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# {1, 2, 3} tipi: <class 'set'> eleman sayısı: 3

# %%
kume.add("abcde")
kume.add((1,2,3))
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# {1, 2, 3, (1, 2, 3), 'abcde'} tipi: <class 'set'> eleman sayısı: 5

# %%
kume.remove(1)
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# {2, 3, (1, 2, 3), 'abcde'} tipi: <class 'set'> eleman sayısı: 4

# %%
kume.remove(4)
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3558648641.py in <cell line: 0>()
# ----> 1 kume.remove(4)
#       2 print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
#
# KeyError: 4

# %%
kume.discard(4)
print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# {2, 3, (1, 2, 3), 'abcde'} tipi: <class 'set'> eleman sayısı: 4

# %%
2 in kume
# Out:
# True

# %%
0 in [1,2,3]
# Out:
# False

# %%
# remove fonksiyonun kullanim amaci
# hatali islem durumlarinda hata ile ilgili anlamli cikti verebilmemizi saglar
# yani hata yonetimini kolaylastirir.
try:
    kume.remove(2)
except KeyError:
    print("Böyle bir eleman yok")

print(f"{kume} tipi: {type(kume)} eleman sayısı: {len(kume)}")
# Out:
# Böyle bir eleman yok
# {3, (1, 2, 3), 'abcde'} tipi: <class 'set'> eleman sayısı: 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = {1,2,3}
B = {2,3,4,5,6}
A | B
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A & B
# Out:
# {2, 3}

# %%
A - B
# Out:
# {1}

# %%
B - A
# Out:
# {4, 5, 6}

# %%
A ^ B
# Out:
# {1, 4, 5, 6}

# %%
B ^ A
# Out:
# {1, 4, 5, 6}

# %%
liste = [1,2,2,2,3,3,"1,2,3"]
liste
# Out:
# [1, 2, 2, 2, 3, 3, '1,2,3']

# %%
{1,2,2,2,3,3,[1,2]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1732057253.py in <cell line: 0>()
# ----> 1 {1,2,2,2,3,3,[1,2]}
#
# TypeError: unhashable type: 'list'

# %%
set(liste)
# Out:
# {1, '1,2,3', 2, 3}

# %%
list(A)
# Out:
# [1, 2, 3]
